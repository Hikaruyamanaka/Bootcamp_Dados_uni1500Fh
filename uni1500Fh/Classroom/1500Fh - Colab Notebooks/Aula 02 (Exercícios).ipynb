# %%
l = 'Marcel'
num = 29
real = 84.5
tupla = ('Hikaru', 'Yamanaka')

lista = [l, num, real, tupla]

print(lista)

dicionario = {'Nome': 'Samuel', 'Peso': 78, 'Altura': 1.85}
print(dicionario[2]) 
# Gera erro porque o número 2 não existe na variável dicionário.

# %%
from pandas.core.frame import DataFrame
import pandas as pd
import numpy as np
import datetime

columns = ['Cor', 'Número']
index = ['a','b','c']
values =  [['azul', 7], ['amarelo', 13], ['verde', 25]]

df = pd.DataFrame(
    data = values,
    index = index,
    columns = columns
)

print(df)
# Out:
#        Cor  Número
# a     azul       7
# b  amarelo      13
# c    verde      25

# %%
columns = ['Altura', 'Peso']
index = ['Alberto', 'Bernardo', 'Carlos']
values = [[1.88, 90], [1.79, 79], [1.67, 72]]

Info = DataFrame(
    data = values,
    index = index,
    columns = columns
)

print(Info)

# %%
df = pd.read_csv('/content/Datas.csv',
            sep = ';',
            parse_dates = ['date_1', 'date_3'],
            dayfirst = True            
)

# %%
df['location']

# %%
df['date_2'].map(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y'))

# %%
df['date_4'] = df['date_4'].map(lambda x: datetime.datetime.strptime(x[0:-1], '%d/%m/%Y %H:%M:%S.%f'))

# %%
df.dtypes
# Out:
# location                       object
# date_1                 datetime64[ns]
# date_2                         object
# date_3                 datetime64[ns]
# date_4                 datetime64[ns]
# variant                        object
# num_sequences                   int64
# perc_sequences                  int64
# num_sequences_total             int64
# dtype: object
